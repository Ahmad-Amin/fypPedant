# %% [markdown]
# > pip install SpeechRecognition

# %%
import speech_recognition as sr
sr.__version__
# Out:
# '3.8.1'

# %%
r = sr.Recognizer()

# %% [markdown]
# ### Recording or Uploading Audio File

# %%
r.recognize_google()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-d49a55a68619> in <module>
# ----> 1 r.recognize_google()
#
# TypeError: recognize_google() missing 1 required positional argument: 'audio_data'

# %%
harvard = sr.AudioFile('Audio 1.wav')
with harvard as source:
    audio = r.record(source)

# %%
type(audio)
# Out:
# speech_recognition.AudioData

# %% [markdown]
# ### Doing it with Google

# %%
r.recognize_google(audio)
# Out:
# 'I am going to the'

# %%
r.recognize_google(audio, show_all=True)
# Out:
# {'alternative': [{'transcript': 'I am going to the', 'confidence': 0.83460408},
#   {'transcript': 'I am going to the back'},
#   {'transcript': 'I am going to the WhatsApp'},
#   {'transcript': 'I am going to'},
#   {'transcript': 'I am going to bus'}],
#  'final': True}

# %% [markdown]
# I have an observation here, that the free google API embeded here in SpeechRecognition library is only taking a few seconds or possibly, the first second of the audio.

# %% [markdown]
# ### Doing it with IBM

# %% [markdown]
# > pip install ibm-watson

# %%
from ibm_watson import SpeechToTextV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
import json

# %%
authenticator = IAMAuthenticator('jXJZ0DFtm0iLg-XinOxqIRgbHlT-376eS3TfNPlFq37i')
service = SpeechToTextV1(
    authenticator=authenticator
)
service.set_service_url('https://api.eu-gb.speech-to-text.watson.cloud.ibm.com/instances/cabe9e09-1272-475f-a3e1-77c4c50ce8d2')

# %%
models = service.list_models().get_result()
print(json.dumps(models, indent=2))

model = service.get_model('en-US_BroadbandModel').get_result()
print(json.dumps(model, indent=2))

with open('Audio 1.wav') as audio_file:
    print(json.dumps(
        service.recognize(
            audio=audio_file,
            content_type='audio/wav',
            timestamps=True,
            word_confidence=True).get_result(),
        indent=2))
# Out:
# {
#   "models": [
#     {
#       "name": "pt-BR_BroadbandModel",
#       "rate": 16000,
#       "language": "pt-BR",
#       "description": "Brazilian Portuguese broadband model.",
#       "supported_features": {
#         "custom_language_model": true,
#         "speaker_labels": true
#       },
#       "url": "https://api.eu-gb.speech-to-text.watson.cloud.ibm.com/instances/cabe9e09-1272-475f-a3e1-77c4c50ce8d2/v1/models/pt-BR_BroadbandModel"
#     },
#     {
#       "name": "en-US_BroadbandModel",
#       "rate": 16000,
#       "language": "en-US",
#       "description": "US English broadband model.",
#       "supported_features": {
#         "custom_language_model": true,
#         "speaker_labels": true
#       },
#       "url": "https://api.eu-gb.speech-to-text.watson.cloud.ibm.com/instances/cabe9e09-1272-475f-a3e1-77c4c50ce8d2/v1/models/en-US_BroadbandModel"
#     },
#     {
#       "name": "zh-CN_BroadbandModel",
#       "rate": 16000,
#       "language": "zh-CN",
# ...

# %%
import json
from os.path import join, dirname
from ibm_watson import SpeechToTextV1
from ibm_watson.websocket import RecognizeCallback, AudioSource
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
  
   
# Insert API Key in place of 
# 'YOUR UNIQUE API KEY'
authenticator = IAMAuthenticator('jXJZ0DFtm0iLg-XinOxqIRgbHlT-376eS3TfNPlFq37i') 
service = SpeechToTextV1(authenticator = authenticator)
   
#Insert URL in place of 'API_URL' 
service.set_service_url('https://api.eu-gb.speech-to-text.watson.cloud.ibm.com/instances/cabe9e09-1272-475f-a3e1-77c4c50ce8d2')
   
# Insert local mp3 file path in
# place of 'LOCAL FILE PATH' 
with open(r'Audio 1.wav', encoding='latin-1') as audio_file:
        dic = json.loads(
                json.dumps(
                    service.recognize(
                        audio=audio_file, timeout=100
                    ).get_result(), indent=2))
  
# Stores the transcribed text
str = ""
  
while bool(dic.get('results')):
    str = dic.get('results').pop().get('alternatives').pop().get('transcript')+str[:]
       
print(str)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /usr/lib/python3/dist-packages/six.py in raise_from(value, from_value)
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#
# /usr/lib/python3.8/http/client.py in getresponse(self)
#    1343             try:
# -> 1344                 response.begin()
# ...

# %%
r.recognize_ibm(audio)

# %%
r.recognize_ibm(audio, show_all=True)
